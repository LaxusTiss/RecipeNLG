# %% [markdown]
# # Recipe Generation Training
#
# Notebook nay duoc tao tu README de chay tren Google Colab voi GPU T4.

# %%
# !pip install -r requirements.txt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !python src/train.py \
  --data_path data/full_dataset.csv \
  --output_dir outputs/recipe-gpt2-final \
  --num_samples 50000 \
  --epochs 3 \
  --batch_size 8 \
  --max_len 512 \
  --fp16

# %%
# !python src/generate.py \
  --model_dir outputs/recipe-gpt2-final \
  --title "Chocolate Lava Cake" \
  --ingredients "chocolate, butter, eggs, sugar, flour"
